# %%
import requests
url = 'https://httpbin.org/get'
response = requests.get(url)
response.status_code
print(response.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68870d72-576fff1a49414a4543eb3b46"
#   },
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/get"
# }

# %%
params = {
    'name' : 'ylee',
    'age' : 20
}
url = 'https://httpbin.org/get'
response = requests.get(url, params=params)
response.status_code
print(response.text)
# Out:
# {
#   "args": {
#     "age": "20",
#     "name": "ylee"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68870e4d-5bd6c0f064d52f3d01f65350"
#   },
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/get?name=ylee&age=20"
# }

# %%
url = 'https://httpbin.org/post'
response = requests.post(url, json={'key':'value'})
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "{\"key\": \"value\"}",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "16",
#     "Content-Type": "application/json",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6887100d-2246315c3b479bfb6e6d3028"
#   },
#   "json": {
#     "key": "value"
#   },
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/post"
# }

# %%
response.json()['headers']['Content-Type']
# Out:
# 'application/x-www-form-urlencoded'

# %%
response.json()['headers']['User-Agent']
# Out:
# 'python-requests/2.32.4'

# %%
response = requests.put('https://httpbin.org/put', data={'key':'value'})
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68871071-6b8eaeef12b075aa51f80135"
#   },
#   "json": null,
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/put"
# }

# %%
response = requests.patch('https://httpbin.org/patch', data={'key':'value'})
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-688710a0-76918e83098c4f43154a5697"
#   },
#   "json": null,
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/patch"
# }
