# %%
import pandas as pd
data_df = pd.read_csv('./data/datalab.csv')
data_df.head()
# Out:
#            날짜      스트레스        상담
# 0  2016-01-01  29.33972   8.83919
# 1  2016-01-02  31.52289  10.64962
# 2  2016-01-03  40.30883  14.48349
# 3  2016-01-04  45.74014  22.41746
# 4  2016-01-05  51.49094  23.58892

# %%
corr_df = data_df[['스트레스', '상담']]
corr_df.corr()
# Out:
#           스트레스        상담
# 스트레스  1.000000  0.725658
# 상담    0.725658  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(corr_df['스트레스'], corr_df['상담'] )
plt.show()

# %%
import pandas as pd
data_df = pd.read_csv('./data/datalab (1).csv')
data_df.head()
# Out:
#            날짜      스트레스        폭력
# 0  2016-01-01  29.33972   5.64430
# 1  2016-01-02  31.52289  10.38338
# 2  2016-01-03  40.30883   8.51970
# 3  2016-01-04  45.74014   9.63791
# 4  2016-01-05  51.49094   8.99893

# %%
corr_df = data_df[['스트레스', '폭력']]
corr_df.corr()
# Out:
#           스트레스        폭력
# 스트레스  1.000000  0.735049
# 폭력    0.735049  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(corr_df['스트레스'], corr_df['폭력'] )
plt.show()

# %%
import pandas as pd
data_df = pd.read_csv('./data/datalab (4).csv')
data_df.head()
# Out:
#            날짜     스트레스        이혼
# 0  2016-01-01  2.98454  15.87395
# 1  2016-01-02  3.31747  16.87277
# 2  2016-01-03  4.68489  20.20214
# 3  2016-01-04  5.29131  15.58858
# 4  2016-01-05  6.13555  12.86563

# %%
corr_df = data_df[['스트레스', '이혼']]
corr_df.corr()
# Out:
#           스트레스        이혼
# 스트레스  1.000000  0.109368
# 이혼    0.109368  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(corr_df['스트레스'], corr_df['이혼'] )
plt.show()

# %%
import pandas as pd
from scipy.stats import pearsonr

# 예시 데이터
data = {
    'height': [160, 165, 170, 175, 180],
    'weight': [50, 55, 65, 70, 80]
}
df = pd.DataFrame(data)

# 피어슨 상관계수 계산
corr, p_value = pearsonr(df['height'], df['weight'])

print(f"피어슨 상관계수: {corr:.2f}")
print(f"p-값: {p_value:.4f}")
# Out:
# 피어슨 상관계수: 0.99
# p-값: 0.0006

# %%
import pandas as pd
from scipy.stats import spearmanr

# 데이터프레임 구성
data = {
    'student': ['A', 'B', 'C', 'D', 'E'],
    'academic_rank': [1, 2, 3, 4, 5],
    'sports_rank': [2, 4, 3, 5, 1]
}
df = pd.DataFrame(data)

# 스피어만 상관계수 계산
rho, pval = spearmanr(df['academic_rank'], df['sports_rank'])

print(f"스피어만 상관계수: {rho:.3f}")
print(f"p-value: {pval:.4f}")
# Out:
# 스피어만 상관계수: -0.100
# p-value: 0.8729

# %%
import pandas as pd
from scipy.stats import kendalltau

# 사람 A~E의 키와 몸무게 순위
data = {
    'Person': ['A', 'B', 'C', 'D', 'E'],
    'Height_rank': [1, 2, 3, 4, 5],     # 키 순위
    'Weight_rank_1': [2, 3, 4, 5, 1],   # τ = 0.2
    'Weight_rank_2': [1, 2, 3, 4, 5],   # τ = 1
    'Weight_rank_3': [5, 4, 3, 2, 1]    # τ = -1
}

df = pd.DataFrame(data)

# 계수 계산
tau1, _ = kendalltau(df['Height_rank'], df['Weight_rank_1'])
tau2, _ = kendalltau(df['Height_rank'], df['Weight_rank_2'])
tau3, _ = kendalltau(df['Height_rank'], df['Weight_rank_3'])

print(f"상관계수 (Weight_rank_1): {tau1:.2f}")
print(f"상관계수 (Weight_rank_2): {tau2:.2f}")
print(f"상관계수 (Weight_rank_3): {tau3:.2f}")
# Out:
# 상관계수 (Weight_rank_1): 0.20
# 상관계수 (Weight_rank_2): 1.00
# 상관계수 (Weight_rank_3): -1.00
